# %%
import pybaseball
from pybaseball import  playerid_lookup
from pybaseball import  statcast_pitcher
import json

# %%
playerid_lookup('imanaga', 'shota')
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   imanaga      shota     684007  imans001  imanash01             -1
#
#    mlb_played_first  mlb_played_last
# 0            2024.0           2024.0

# %%
imanaga_stats = statcast_pitcher('2024-03-28', '2024-05-08', 684007)
# Out:
# Gathering Player Data

# %%
imanaga_stats.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FS  2024-05-07           83.7           2.73           5.35
# 1         FS  2024-05-07           82.0           2.65           5.29
# 2         FS  2024-05-07           83.4           2.56           5.37
# 3         FS  2024-05-07           82.9           2.72           5.34
# 4         FS  2024-05-07           81.1           2.64           5.35
#
#       player_name  batter  pitcher    events      description  ...  fld_score  \
# 0  Imanaga, Shota  595777   684007  home_run    hit_into_play  ...          1
# 1  Imanaga, Shota  595777   684007       NaN  swinging_strike  ...          1
# 2  Imanaga, Shota  595777   684007       NaN             ball  ...          1
# 3  Imanaga, Shota  595777   684007       NaN             ball  ...          1
# 4  Imanaga, Shota  595777   684007       NaN  swinging_strike  ...          1
#
#    post_away_score  post_home_score  post_bat_score  post_fld_score  \
# ...

# %%
imanaga_stats.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
imanaga_stats['release_spin_rate']
# Out:
# 0      1237
# 1      1124
# 2      1399
# 3      1215
# 4      1379
#        ...
# 589    1010
# 590    2505
# 591    2382
# 592    2552
# 593    2517
# Name: release_spin_rate, Length: 594, dtype: int64

# %%
subset_imanaga = imanaga_stats[['game_date', 'pitch_type', 'plate_x', 'plate_z', 'effective_speed', 'release_spin_rate', 'description']]
subset_imanaga
# Out:
#       game_date pitch_type  plate_x  plate_z  effective_speed  \
# 0    2024-05-07         FS     0.33     1.49             84.2
# 1    2024-05-07         FS     0.32     1.85             82.4
# 2    2024-05-07         FS    -0.83     0.87             83.9
# 3    2024-05-07         FS    -0.86     0.98             83.3
# 4    2024-05-07         FS     0.18     1.25             81.5
# ..          ...        ...      ...      ...              ...
# 589  2024-04-01         FS     0.53     1.35             84.0
# 590  2024-04-01         FF     0.15     3.61             92.6
# 591  2024-04-01         FF    -0.06     2.85             92.5
# 592  2024-04-01         FF    -1.30     3.26             93.7
# 593  2024-04-01         FF     0.21     2.32             91.8
#
#      release_spin_rate      description
# 0                 1237    hit_into_play
# 1                 1124  swinging_strike
# 2                 1399             ball
# 3                 1215             ball
# ...

# %%
subset_imanaga['pitch_type'].unique()
# Out:
# array(['FS', 'FF', 'CH', 'ST', 'CU', 'SI'], dtype=object)

# %%
subset_imanaga['pitch_type'].value_counts()
# Out:
# FF    344
# FS    180
# ST     45
# CU     21
# SI      3
# CH      1
# Name: pitch_type, dtype: int64

# %%
subset_imanaga.to_json('imanaga.json', orient='records')
